# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

base_url = "https://gist.githubusercontent.com/alti-tude/710cb9d4dfc7ebcd0afb9cf93d8f6a8d/raw/574730ba009e69b81d6c79f2fef2c3dd5145db0a/"

# %%
purchases = pd.read_csv(base_url + "purchases.csv", index_col = 0)
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
movies = pd.read_csv(base_url + "IMDB-Movie-Data.csv", index_col = 0)
movies
# Out:
#                         Title  ... Metascore
# Rank                           ...
# 1     Guardians of the Galaxy  ...      76.0
# 2                  Prometheus  ...      65.0
# 3                       Split  ...      62.0
# 4                        Sing  ...      59.0
# 5               Suicide Squad  ...      40.0
# ...                       ...  ...       ...
# 996      Secret in Their Eyes  ...      45.0
# 997           Hostel: Part II  ...      46.0
# 998    Step Up 2: The Streets  ...      50.0
# 999              Search Party  ...      22.0
# 1000               Nine Lives  ...      11.0
#
# [1000 rows x 11 columns]

# %%
music = pd.read_csv(base_url + "MusicTop50.csv", index_col=0)
music
# Out:
#                                            Track.Name  ... Popularity
# 1                                            Se�orita  ...       79.0
# 2                                               China  ...       92.0
# 3                       boyfriend (with Social House)  ...       85.0
# 4                     Beautiful People (feat. Khalid)  ...       86.0
# 5                         Goodbyes (Feat. Young Thug)  ...       94.0
# 6                   I Don't Care (with Justin Bieber)  ...       84.0
# 7                                              Ransom  ...       92.0
# 8                                   How Do You Sleep?  ...       90.0
# 9                               Old Town Road - Remix  ...       87.0
# 10                                            bad guy  ...       95.0
# 11                                           Callaita  ...       93.0
# 12              Loco Contigo (feat. J. Balvin & Tyga)  ...        NaN
# ...

# %%
music.head()
# Out:
#                         Track.Name    Artist.Name  ... Speechiness  Popularity
# 1                         Se�orita   Shawn Mendes  ...           3        79.0
# 2                            China       Anuel AA  ...           9        92.0
# 3    boyfriend (with Social House)  Ariana Grande  ...          46        85.0
# 4  Beautiful People (feat. Khalid)     Ed Sheeran  ...          19        86.0
# 5      Goodbyes (Feat. Young Thug)    Post Malone  ...           7        94.0
#
# [5 rows x 13 columns]

# %%
music.tail()
# Out:
#                                        Track.Name  ... Popularity
# 46                                One Thing Right  ...       88.0
# 47                                      Te Robar�  ...       88.0
# 48                                        Happier  ...       88.0
# 49                                  Call You Mine  ...       88.0
# 50  Cross Me (feat. Chance the Rapper & PnB Rock)  ...       82.0
#
# [5 rows x 13 columns]

# %%
music.columns = ["key","Artist", "genre", "BPM","energy","dance++","LOUD","LIVE","valence","length","acou", "speech","popularity" ]
music
# Out:
#                                                   key  ... popularity
# 1                                            Se�orita  ...       79.0
# 2                                               China  ...       92.0
# 3                       boyfriend (with Social House)  ...       85.0
# 4                     Beautiful People (feat. Khalid)  ...       86.0
# 5                         Goodbyes (Feat. Young Thug)  ...       94.0
# 6                   I Don't Care (with Justin Bieber)  ...       84.0
# 7                                              Ransom  ...       92.0
# 8                                   How Do You Sleep?  ...       90.0
# 9                               Old Town Road - Remix  ...       87.0
# 10                                            bad guy  ...       95.0
# 11                                           Callaita  ...       93.0
# 12              Loco Contigo (feat. J. Balvin & Tyga)  ...        NaN
# ...

# %%
music.dropna()
# Out:
#                                                   key  ... popularity
# 1                                            Se�orita  ...       79.0
# 2                                               China  ...       92.0
# 3                       boyfriend (with Social House)  ...       85.0
# 4                     Beautiful People (feat. Khalid)  ...       86.0
# 6                   I Don't Care (with Justin Bieber)  ...       84.0
# 8                                   How Do You Sleep?  ...       90.0
# 9                               Old Town Road - Remix  ...       87.0
# 10                                            bad guy  ...       95.0
# 13                                  Someone You Loved  ...       88.0
# 14                                 Otro Trago - Remix  ...       87.0
# 15           Money In The Grave (Drake ft. Rick Ross)  ...       92.0
# 16                          No Guidance (feat. Drake)  ...       82.0
# ...

# %%
mean = music.mean()
music.fillna(mean)
# Out:
#                                                   key  ... popularity
# 1                                            Se�orita  ...  79.000000
# 2                                               China  ...  92.000000
# 3                       boyfriend (with Social House)  ...  85.000000
# 4                     Beautiful People (feat. Khalid)  ...  86.000000
# 5                         Goodbyes (Feat. Young Thug)  ...  94.000000
# 6                   I Don't Care (with Justin Bieber)  ...  84.000000
# 7                                              Ransom  ...  92.000000
# 8                                   How Do You Sleep?  ...  90.000000
# 9                               Old Town Road - Remix  ...  87.000000
# 10                                            bad guy  ...  95.000000
# 11                                           Callaita  ...  93.000000
# 12              Loco Contigo (feat. J. Balvin & Tyga)  ...  87.530612
# ...

# %%
med = music.median()
music.fillna(med)
# Out:
#                                                   key  ... popularity
# 1                                            Se�orita  ...       79.0
# 2                                               China  ...       92.0
# 3                       boyfriend (with Social House)  ...       85.0
# 4                     Beautiful People (feat. Khalid)  ...       86.0
# 5                         Goodbyes (Feat. Young Thug)  ...       94.0
# 6                   I Don't Care (with Justin Bieber)  ...       84.0
# 7                                              Ransom  ...       92.0
# 8                                   How Do You Sleep?  ...       90.0
# 9                               Old Town Road - Remix  ...       87.0
# 10                                            bad guy  ...       95.0
# 11                                           Callaita  ...       93.0
# 12              Loco Contigo (feat. J. Balvin & Tyga)  ...       88.0
# ...

# %% [markdown]
# #Max loudness of artist with min popularity

# %%
min_pop = music["popularity"].min()
artist = music[music["popularity"] ==  min_pop]

print(artist["Artist"])

max_loud = artist["LOUD"].max()
print(max_loud)
# Out:
# 26    Shawn Mendes
# Name: Artist, dtype: object
# -4
